# %% [markdown]
# # Import files

# %%
# !pip install -q -U PyDrive # to get access to files

# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

file_id = '1M1-iIMEj4OVdKKN-pYrVpkHqMvm2M26h'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('Assignment_2.zip')
# !unzip -q Assignment_2.zip
# !ls Assignment_2

path = 'Assignment_2'
# Out:
# 'correct csv.ipynb'		  ex2_FCnet.py	      __pycache__
# 'corrected results.csv'		  ex2_pytorch.py      results
# 'corrected results_renamed.csv'   get_datasets.sh     simul.csv
#  datasets			  gradient_check.py   two_layernet.py
#  data_utils.py			  plot_x_overleaf     vis_utils.py

# %% [markdown]
# # Implementation of two layered MLP

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# %%
def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 1e-3)
        m.bias.data.fill_(0.)

def update_lr(optimizer, lr):
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

#--------------------------------
# Device configuration
#--------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device: %s'%device)

#--------------------------------
# Hyper-parameters
#--------------------------------
input_size = 32 * 32 * 3
hidden_size = [50]
num_classes = 10
num_epochs = 10
batch_size = 200
learning_rate = 1e-3
learning_rate_decay = 0.95
reg=0.001
num_training= 49000
num_validation =1000
train = True

#-------------------------------------------------
# Load the CIFAR-10 dataset
#-------------------------------------------------
norm_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])
cifar_dataset = torchvision.datasets.CIFAR10(root=path+'datasets/',
                                           train=True,
                                           transform=norm_transform,
                                           download=True)

test_dataset = torchvision.datasets.CIFAR10(root=path+'datasets/',
                                          train=False,
                                          transform=norm_transform
                                          )
#-------------------------------------------------
# Prepare the training and validation splits
#-------------------------------------------------
mask = list(range(num_training))
train_dataset = torch.utils.data.Subset(cifar_dataset, mask)
mask = list(range(num_training, num_training + num_validation))
val_dataset = torch.utils.data.Subset(cifar_dataset, mask)

#-------------------------------------------------
# Data loader
#-------------------------------------------------
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)
# Out:
# Using device: cuda
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to Assignment_2datasets/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting Assignment_2datasets/cifar-10-python.tar.gz to Assignment_2datasets/

# %%
torch.manual_seed(123)
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes):
        super(MultiLayerPerceptron, self).__init__() # it writes initialization for nn.Module class as well 
        #################################################################################
        # TODO: Initialize the modules required to implement the mlp with the layer     #
        # configuration. input_size --> hidden_layers[0] --> hidden_layers[1] .... -->  #
        # hidden_layers[-1] --> num_classes                                             #
        # Make use of linear and relu layers from the torch.nn module                   #
        #################################################################################
        
        layers = [] #Use the layers list to store a variable number of layers
        
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        layers.append(nn.Linear(input_size, hidden_layers[0]))
        layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[0], num_classes))
  

        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # Enter the layers into nn.Sequential, so the model may "see" them
        # Note the use of * in front of layers
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        #################################################################################
        # TODO: Implement the forward pass computations                                 #
        # Note that you do not need to use the softmax operation at the end.            #
        # Softmax is only required for the loss computation and the criterion used below#
        # nn.CrossEntropyLoss() already integrates the softmax and the log loss together#
        #################################################################################
        
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        out = self.layers(x)
        

        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        
        return out

model = MultiLayerPerceptron(input_size, hidden_size, num_classes).to(device)
# Print model's state_dict
'''
print("Model's state_dict:")
for param_tensor in model.state_dict():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())
'''

if train:
    model.apply(weights_init)
    model.train() #set dropout and batch normalization layers to training mode

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

    # Train the model
    lr = learning_rate
    total_step = len(train_loader)
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            # Move tensors to the configured device
            images = images.to(device)
            labels = labels.to(device)
            #################################################################################
            # TODO: Implement the training code                                             #
            # 1. Pass the images to the model                                               #
            # 2. Compute the loss using the output and the labels.                          #
            # 3. Compute gradients and update the model using the optimizer                 #
            # Use examples in https://pytorch.org/tutorials/beginner/pytorch_with_examples.html
            #################################################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            # Pass images to the model to compute predicted labels
            images = images.view(-1, input_size)
            pred_labels = model(images) 
            
            
            # Compute the loss using the predicted labels and the actual labels.
            loss = criterion(pred_labels, labels)

            # Compute gradients and update the model using the optimizer
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()


            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

            if (i+1) % 100 == 0:
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                       .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

        # Code to update the lr
        lr *= learning_rate_decay
        update_lr(optimizer, lr)
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                ####################################################
                # TODO: Implement the evaluation code              #
                # 1. Pass the images to the model                  #
                # 2. Get the most confident predicted class        #
                ####################################################
                # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
                images = images.view(-1, input_size)
                predicted = torch.argmax(model(images), dim=1)


                # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            print('Validataion accuracy is: {} %'.format(100 * correct / total))
    ##################################################################################
    # TODO: Now that you can train a simple two-layer MLP using above code, you can  #
    # easily experiment with adding more layers and different layer configurations   #
    # and let the pytorch library handle computing the gradients                     #
    #                                                                                #
    # Experiment with different number of layers (at least from 2 to 5 layers) and   #
    # record the final validation accuracies Report your observations on how adding  #
    # more layers to the MLP affects its behavior. Try to improve the model          #
    # configuration using the validation performance as the guidance. You can        #
    # experiment with different activation layers available in torch.nn, adding      #
    # dropout layers, if you are interested. Use the best model on the validation    #
    # set, to evaluate the performance on the test set once and report it            #
    ##################################################################################

    # Save the model checkpoint
    torch.save(model.state_dict(), 'model.ckpt')

else:
    # Run the test code once you have your by setting train flag to false
    # and loading the best model

    best_model = None
    best_model = torch.load('model.ckpt')
    
    model.load_state_dict(best_model)
    
    # Test the model
    model.eval() #set dropout and batch normalization layers to evaluation mode
    
    # In test phase, we don't need to compute gradients (for memory efficiency)
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            ####################################################
            # TODO: Implement the evaluation code              #
            # 1. Pass the images to the model                  #
            # 2. Get the most confident predicted class        #
            ####################################################
            # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            images = images.view(-1, input_size)
            predicted = torch.argmax(model(images), dim=1)


            # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            if total == 1000:
                break

        print('Accuracy of the network on the {} test images: {} %'.format(total, 100 * correct / total))
# Out:
# Epoch [1/10], Step [100/245], Loss: 1.7975
# Epoch [1/10], Step [200/245], Loss: 1.7045
# Validataion accuracy is: 44.1 %
# Epoch [2/10], Step [100/245], Loss: 1.4979
# Epoch [2/10], Step [200/245], Loss: 1.5327
# Validataion accuracy is: 46.1 %
# Epoch [3/10], Step [100/245], Loss: 1.4750
# Epoch [3/10], Step [200/245], Loss: 1.5688
# Validataion accuracy is: 47.9 %
# Epoch [4/10], Step [100/245], Loss: 1.5602
# Epoch [4/10], Step [200/245], Loss: 1.4943
# Validataion accuracy is: 49.9 %
# Epoch [5/10], Step [100/245], Loss: 1.3469
# Epoch [5/10], Step [200/245], Loss: 1.4505
# Validataion accuracy is: 48.7 %
# Epoch [6/10], Step [100/245], Loss: 1.2933
# Epoch [6/10], Step [200/245], Loss: 1.5111
# Validataion accuracy is: 50.5 %
# Epoch [7/10], Step [100/245], Loss: 1.3567
# Epoch [7/10], Step [200/245], Loss: 1.3667
# Validataion accuracy is: 50.7 %
# Epoch [8/10], Step [100/245], Loss: 1.3137
# Epoch [8/10], Step [200/245], Loss: 1.2753
# Validataion accuracy is: 50.9 %
# Epoch [9/10], Step [100/245], Loss: 1.2609
# Epoch [9/10], Step [200/245], Loss: 1.2787
# Validataion accuracy is: 51.0 %
# Epoch [10/10], Step [100/245], Loss: 1.1911
# Epoch [10/10], Step [200/245], Loss: 1.3975
# Validataion accuracy is: 51.1 %

# %% [markdown]
# # Grid search

# %%
import pandas as pd
from sklearn.model_selection import ParameterGrid
from tqdm import tqdm_notebook as tqdm

torch.manual_seed(123)
class MultiLayerPerceptronGridSearch(nn.Module):
    def __init__(self, input_size, hidden_layers, num_classes, num_layers, activation_func, dropout=False):
        super(MultiLayerPerceptronGridSearch, self).__init__() # it writes initialization for nn.Module class as well 
        #################################################################################
        # TODO: Initialize the modules required to implement the mlp with the layer     #
        # configuration. input_size --> hidden_layers[0] --> hidden_layers[1] .... -->  #
        # hidden_layers[-1] --> num_classes                                             #
        # Make use of linear and relu layers from the torch.nn module                   #
        #################################################################################
        
        layers = [] #Use the layers list to store a variable number of layers
        
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # input
        layers.append(nn.Linear(input_size, hidden_layers[0]))
        layers.append(activation_func)  
        if dropout == True: layers.append(nn.Dropout(p=0.3))

        # following layers
        for layer in range(num_layers-1):   
          layers.append(nn.Linear(hidden_layers[0], hidden_layers[0]))
          layers.append(activation_func) 
          if dropout == True: layers.append(nn.Dropout(p=0.3))

        # output 
        layers.append(nn.Linear(hidden_layers[0], num_classes))
          

        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

        # Enter the layers into nn.Sequential, so the model may "see" them
        # Note the use of * in front of layers
        self.layers = nn.Sequential(*layers)

    def forward(self, x):
        #################################################################################
        # TODO: Implement the forward pass computations                                 #
        # Note that you do not need to use the softmax operation at the end.            #
        # Softmax is only required for the loss computation and the criterion used below#
        # nn.CrossEntropyLoss() already integrates the softmax and the log loss together#
        #################################################################################
        
        # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        out = self.layers(x)
        

        # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
        
        return out

hyper_grid = {'num_layers': [2, 3, 4, 5, 10, 15], 'activation_func' : [nn.ReLU(), nn.PReLU(), nn.LeakyReLU(), nn.Sigmoid(), nn.Tanh()], 'flag':[True, False]}
grid = ParameterGrid(hyper_grid)
all_res = []
for hypers in tqdm(grid):

  # hyperparameters combination
  num_layers = hypers['num_layers']
  activation_func = hypers['activation_func']
  flag = hypers['flag']
  print('\n\n\n\nHyperparameters: num_layers = '+str(num_layers)+', activation_func = '+str(activation_func)+', flag = '+str(flag))

  # initialize model
  model = MultiLayerPerceptronGridSearch(input_size, hidden_size, num_classes, num_layers, activation_func, dropout=flag).to(device)

  model.apply(weights_init)
  
  # Loss and optimizer
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=reg)

  # Train the model
  lr = learning_rate
  total_step = len(train_loader)
  for epoch in range(num_epochs):
      correct_train = 0
      total_train = 0
      model.train()
      for i, (images, labels) in enumerate(train_loader):
          # Move tensors to the configured device
          images = images.to(device)
          labels = labels.to(device)
          #################################################################################
          # TODO: Implement the training code                                             #
          # 1. Pass the images to the model                                               #
          # 2. Compute the loss using the output and the labels.                          #
          # 3. Compute gradients and update the model using the optimizer                 #
          # Use examples in https://pytorch.org/tutorials/beginner/pytorch_with_examples.html
          #################################################################################
          # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

          # Pass images to the model to compute predicted labels
          images = images.view(-1, input_size)
          pred_labels = model(images) 
          

          # Compute the loss using the predicted labels and the actual labels.
          loss = criterion(pred_labels, labels)

          # Compute gradients and update the model using the optimizer
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          # Compute train accuracy
          predicted = torch.argmax(pred_labels, dim=1)
          total_train += labels.size(0)
          correct_train += (predicted == labels).sum().item()

          # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

          if (i+1) % 100 == 0:
              print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                      .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

      # Code to update the lr
      lr *= learning_rate_decay
      update_lr(optimizer, lr)
      with torch.no_grad():
          correct = 0
          total = 0
          model.eval()
          for images, labels in val_loader:
              images = images.to(device)
              labels = labels.to(device)
              ####################################################
              # TODO: Implement the evaluation code              #
              # 1. Pass the images to the model                  #
              # 2. Get the most confident predicted class        #
              ####################################################
              # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
              images = images.view(-1, input_size)
              predicted = torch.argmax(model(images), dim=1)


              # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
              total += labels.size(0)
              correct += (predicted == labels).sum().item()

          print('Validataion accuracy is: {} %'.format(100 * correct / total))
  all_res.append({'N. layers': num_layers, 'Activation': str(activation_func), 'Dropout': flag, 'train_acc': (100 * correct_train / total), 'val_acc': (100 * correct / total)})

# Save result in a dataframe
out_rs = pd.DataFrame(all_res)
out_rs.to_csv('/content/drive/My Drive/MLP_grid_search.csv', index=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(IntProgress(value=0, max=60), HTML(value='')))
# Hyperparameters: num_layers = 2, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 1.9975
# Epoch [1/10], Step [200/245], Loss: 1.9415
# Validataion accuracy is: 36.5 %
# Epoch [2/10], Step [100/245], Loss: 1.6881
# Epoch [2/10], Step [200/245], Loss: 1.7245
# Validataion accuracy is: 40.7 %
# Epoch [3/10], Step [100/245], Loss: 1.6677
# Epoch [3/10], Step [200/245], Loss: 1.8874
# Validataion accuracy is: 42.4 %
# Epoch [4/10], Step [100/245], Loss: 1.7384
# Epoch [4/10], Step [200/245], Loss: 1.6402
# Validataion accuracy is: 43.8 %
# Epoch [5/10], Step [100/245], Loss: 1.6779
# Epoch [5/10], Step [200/245], Loss: 1.7089
# Validataion accuracy is: 46.0 %
# Epoch [6/10], Step [100/245], Loss: 1.7210
# Epoch [6/10], Step [200/245], Loss: 1.6175
# Validataion accuracy is: 46.7 %
# Epoch [7/10], Step [100/245], Loss: 1.5776
# Epoch [7/10], Step [200/245], Loss: 1.5729
# Validataion accuracy is: 47.6 %
# Epoch [8/10], Step [100/245], Loss: 1.5659
# Epoch [8/10], Step [200/245], Loss: 1.6870
# Validataion accuracy is: 48.9 %
# Epoch [9/10], Step [100/245], Loss: 1.6301
# Epoch [9/10], Step [200/245], Loss: 1.6171
# Validataion accuracy is: 48.8 %
# Epoch [10/10], Step [100/245], Loss: 1.5931
# Epoch [10/10], Step [200/245], Loss: 1.6693
# Validataion accuracy is: 48.9 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 8.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3028
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3026
# Epoch [4/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3035
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3032
# Epoch [7/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3025
# Epoch [8/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3024
# Epoch [9/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3022
# Epoch [10/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3032
# Epoch [1/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 10.2 %
# Epoch [2/10], Step [100/245], Loss: 2.3026
# Epoch [2/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3021
# Epoch [3/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3026
# Epoch [4/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 9.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3030
# Epoch [5/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 10.7 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3025
# Epoch [7/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3027
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 10.2 %
# Epoch [9/10], Step [100/245], Loss: 2.3025
# Epoch [9/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3030
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3025
# Epoch [1/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3030
# Epoch [2/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3023
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3027
# Epoch [4/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3026
# Epoch [5/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3031
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3019
# Epoch [7/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3016
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3030
# Epoch [10/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3034
# Validataion accuracy is: 11.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3036
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3031
# Epoch [4/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3028
# Epoch [5/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3029
# Epoch [6/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3024
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3025
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3024
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = ReLU(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3027
# Epoch [2/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 10.2 %
# Epoch [3/10], Step [100/245], Loss: 2.3033
# Epoch [3/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3022
# Epoch [4/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3023
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3023
# Epoch [6/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3019
# Epoch [7/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3030
# Epoch [8/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3022
# Epoch [10/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 1.9753
# Epoch [1/10], Step [200/245], Loss: 1.8962
# Validataion accuracy is: 35.8 %
# Epoch [2/10], Step [100/245], Loss: 1.6466
# Epoch [2/10], Step [200/245], Loss: 1.5105
# Validataion accuracy is: 43.6 %
# Epoch [3/10], Step [100/245], Loss: 1.5621
# Epoch [3/10], Step [200/245], Loss: 1.5858
# Validataion accuracy is: 46.5 %
# Epoch [4/10], Step [100/245], Loss: 1.5320
# Epoch [4/10], Step [200/245], Loss: 1.4555
# Validataion accuracy is: 47.9 %
# Epoch [5/10], Step [100/245], Loss: 1.4315
# Epoch [5/10], Step [200/245], Loss: 1.3777
# Validataion accuracy is: 48.9 %
# Epoch [6/10], Step [100/245], Loss: 1.4035
# Epoch [6/10], Step [200/245], Loss: 1.4524
# Validataion accuracy is: 49.6 %
# Epoch [7/10], Step [100/245], Loss: 1.4252
# Epoch [7/10], Step [200/245], Loss: 1.3122
# Validataion accuracy is: 51.0 %
# Epoch [8/10], Step [100/245], Loss: 1.4061
# Epoch [8/10], Step [200/245], Loss: 1.4504
# Validataion accuracy is: 51.4 %
# Epoch [9/10], Step [100/245], Loss: 1.3482
# Epoch [9/10], Step [200/245], Loss: 1.2538
# Validataion accuracy is: 51.5 %
# Epoch [10/10], Step [100/245], Loss: 1.2132
# Epoch [10/10], Step [200/245], Loss: 1.4166
# Validataion accuracy is: 51.8 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3024
# Epoch [2/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3023
# Epoch [3/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3025
# Epoch [4/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3022
# Epoch [5/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3029
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3028
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3024
# Epoch [9/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3028
# Epoch [10/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3033
# Epoch [4/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3030
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3027
# Epoch [6/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3023
# Epoch [7/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3025
# Epoch [8/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3027
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
# Epoch [10/10], Step [100/245], Loss: 2.3024
# Epoch [10/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3025
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 9.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3028
# Epoch [2/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3028
# Epoch [3/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3022
# Epoch [4/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 9.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3023
# Epoch [5/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [6/10], Step [100/245], Loss: 2.3025
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 10.2 %
# Epoch [7/10], Step [100/245], Loss: 2.3023
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3027
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3027
# Epoch [9/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3035
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3026
# Epoch [1/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 10.5 %
# Epoch [2/10], Step [100/245], Loss: 2.3025
# Epoch [2/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3034
# Epoch [3/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3021
# Epoch [4/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3028
# Epoch [5/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 8.7 %
# Epoch [6/10], Step [100/245], Loss: 2.3029
# Epoch [6/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3031
# Epoch [7/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3024
# Epoch [8/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3014
# Epoch [9/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [10/10], Step [100/245], Loss: 2.3028
# Epoch [10/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 8.7 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = ReLU(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3035
# Epoch [2/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3025
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3028
# Epoch [4/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3030
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3023
# Epoch [7/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3023
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3025
# Epoch [9/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3029
# Epoch [10/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.0232
# Epoch [1/10], Step [200/245], Loss: 1.8837
# Validataion accuracy is: 36.1 %
# Epoch [2/10], Step [100/245], Loss: 1.8871
# Epoch [2/10], Step [200/245], Loss: 1.7969
# Validataion accuracy is: 40.8 %
# Epoch [3/10], Step [100/245], Loss: 1.7563
# Epoch [3/10], Step [200/245], Loss: 1.7819
# Validataion accuracy is: 43.4 %
# Epoch [4/10], Step [100/245], Loss: 1.6731
# Epoch [4/10], Step [200/245], Loss: 1.5473
# Validataion accuracy is: 44.1 %
# Epoch [5/10], Step [100/245], Loss: 1.7112
# Epoch [5/10], Step [200/245], Loss: 1.6485
# Validataion accuracy is: 45.8 %
# Epoch [6/10], Step [100/245], Loss: 1.5957
# Epoch [6/10], Step [200/245], Loss: 1.6488
# Validataion accuracy is: 46.7 %
# Epoch [7/10], Step [100/245], Loss: 1.7177
# Epoch [7/10], Step [200/245], Loss: 1.7099
# Validataion accuracy is: 48.2 %
# Epoch [8/10], Step [100/245], Loss: 1.5843
# Epoch [8/10], Step [200/245], Loss: 1.5729
# Validataion accuracy is: 47.1 %
# Epoch [9/10], Step [100/245], Loss: 1.6183
# Epoch [9/10], Step [200/245], Loss: 1.5585
# Validataion accuracy is: 48.2 %
# Epoch [10/10], Step [100/245], Loss: 1.6569
# Epoch [10/10], Step [200/245], Loss: 1.6621
# Validataion accuracy is: 48.5 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3023
# Epoch [1/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3031
# Epoch [3/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3021
# Epoch [4/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3023
# Epoch [5/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3019
# Epoch [6/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3019
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3027
# Epoch [8/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3025
# Epoch [9/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3021
# Epoch [10/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3031
# Epoch [1/10], Step [200/245], Loss: 2.3035
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3026
# Epoch [2/10], Step [200/245], Loss: 2.3035
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3028
# Epoch [3/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3014
# Epoch [4/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3025
# Epoch [5/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3034
# Epoch [6/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3029
# Epoch [7/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3026
# Epoch [8/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3026
# Epoch [9/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3025
# Epoch [10/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3020
# Epoch [1/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3038
# Epoch [2/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3041
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3028
# Epoch [4/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3029
# Epoch [5/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3037
# Epoch [6/10], Step [200/245], Loss: 2.3035
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3026
# Epoch [7/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3032
# Epoch [8/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3025
# Epoch [9/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3025
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3033
# Epoch [1/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3022
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3024
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 10.5 %
# Epoch [4/10], Step [100/245], Loss: 2.3028
# Epoch [4/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 9.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3019
# Epoch [7/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 9.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3024
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3023
# Epoch [9/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3028
# Epoch [10/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = PReLU(num_parameters=1), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3031
# Epoch [1/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3030
# Epoch [2/10], Step [200/245], Loss: 2.3035
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3023
# Epoch [3/10], Step [200/245], Loss: 2.3034
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3021
# Epoch [4/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3030
# Epoch [5/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3023
# Epoch [7/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3028
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3026
# Epoch [9/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3023
# Epoch [10/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 8.7 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 1.9821
# Epoch [1/10], Step [200/245], Loss: 1.8393
# Validataion accuracy is: 37.4 %
# Epoch [2/10], Step [100/245], Loss: 1.7635
# Epoch [2/10], Step [200/245], Loss: 1.6860
# Validataion accuracy is: 44.6 %
# Epoch [3/10], Step [100/245], Loss: 1.4993
# Epoch [3/10], Step [200/245], Loss: 1.5637
# Validataion accuracy is: 46.3 %
# Epoch [4/10], Step [100/245], Loss: 1.4163
# Epoch [4/10], Step [200/245], Loss: 1.5375
# Validataion accuracy is: 46.2 %
# Epoch [5/10], Step [100/245], Loss: 1.3887
# Epoch [5/10], Step [200/245], Loss: 1.4256
# Validataion accuracy is: 49.5 %
# Epoch [6/10], Step [100/245], Loss: 1.3412
# Epoch [6/10], Step [200/245], Loss: 1.4134
# Validataion accuracy is: 48.9 %
# Epoch [7/10], Step [100/245], Loss: 1.2535
# Epoch [7/10], Step [200/245], Loss: 1.4182
# Validataion accuracy is: 49.6 %
# Epoch [8/10], Step [100/245], Loss: 1.4219
# Epoch [8/10], Step [200/245], Loss: 1.3269
# Validataion accuracy is: 50.1 %
# Epoch [9/10], Step [100/245], Loss: 1.2229
# Epoch [9/10], Step [200/245], Loss: 1.4162
# Validataion accuracy is: 51.6 %
# Epoch [10/10], Step [100/245], Loss: 1.4470
# Epoch [10/10], Step [200/245], Loss: 1.2480
# Validataion accuracy is: 51.3 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3031
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3028
# Epoch [2/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3031
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3029
# Epoch [4/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3025
# Epoch [5/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 10.2 %
# Epoch [7/10], Step [100/245], Loss: 2.3027
# Epoch [7/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3024
# Epoch [8/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3026
# Epoch [10/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3033
# Epoch [1/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 10.2 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3025
# Epoch [3/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3021
# Epoch [4/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3029
# Epoch [5/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3027
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3027
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3020
# Epoch [9/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3026
# Epoch [10/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3023
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 10.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3031
# Epoch [2/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3024
# Epoch [3/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3019
# Epoch [4/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3024
# Epoch [5/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3030
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3026
# Epoch [7/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3022
# Epoch [8/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3024
# Epoch [9/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3031
# Epoch [10/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 9.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3028
# Epoch [4/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3020
# Epoch [5/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3042
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3029
# Epoch [7/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 11.2 %
# Epoch [8/10], Step [100/245], Loss: 2.3022
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3028
# Epoch [9/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3034
# Epoch [10/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = PReLU(num_parameters=1), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 10.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3023
# Epoch [2/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3030
# Epoch [3/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3026
# Epoch [4/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3030
# Epoch [5/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3027
# Epoch [6/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3028
# Epoch [7/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3023
# Epoch [8/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 9.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3026
# Epoch [9/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3025
# Epoch [10/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 1.8903
# Epoch [1/10], Step [200/245], Loss: 1.8630
# Validataion accuracy is: 36.6 %
# Epoch [2/10], Step [100/245], Loss: 1.7654
# Epoch [2/10], Step [200/245], Loss: 1.7473
# Validataion accuracy is: 41.3 %
# Epoch [3/10], Step [100/245], Loss: 1.7809
# Epoch [3/10], Step [200/245], Loss: 1.7070
# Validataion accuracy is: 42.2 %
# Epoch [4/10], Step [100/245], Loss: 1.6810
# Epoch [4/10], Step [200/245], Loss: 1.7031
# Validataion accuracy is: 44.8 %
# Epoch [5/10], Step [100/245], Loss: 1.6207
# Epoch [5/10], Step [200/245], Loss: 1.5192
# Validataion accuracy is: 47.2 %
# Epoch [6/10], Step [100/245], Loss: 1.6557
# Epoch [6/10], Step [200/245], Loss: 1.6417
# Validataion accuracy is: 47.7 %
# Epoch [7/10], Step [100/245], Loss: 1.6438
# Epoch [7/10], Step [200/245], Loss: 1.7413
# Validataion accuracy is: 47.8 %
# Epoch [8/10], Step [100/245], Loss: 1.6711
# Epoch [8/10], Step [200/245], Loss: 1.6720
# Validataion accuracy is: 47.6 %
# Epoch [9/10], Step [100/245], Loss: 1.7253
# Epoch [9/10], Step [200/245], Loss: 1.5226
# Validataion accuracy is: 46.7 %
# Epoch [10/10], Step [100/245], Loss: 1.6606
# Epoch [10/10], Step [200/245], Loss: 1.6109
# Validataion accuracy is: 47.6 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3029
# Epoch [1/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 10.7 %
# Epoch [2/10], Step [100/245], Loss: 2.3033
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 10.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3044
# Epoch [3/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3029
# Epoch [4/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3024
# Epoch [5/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3020
# Epoch [6/10], Step [200/245], Loss: 2.0486
# Validataion accuracy is: 23.1 %
# Epoch [7/10], Step [100/245], Loss: 1.9026
# Epoch [7/10], Step [200/245], Loss: 1.8887
# Validataion accuracy is: 37.3 %
# Epoch [8/10], Step [100/245], Loss: 1.8373
# Epoch [8/10], Step [200/245], Loss: 1.8931
# Validataion accuracy is: 39.7 %
# Epoch [9/10], Step [100/245], Loss: 1.8464
# Epoch [9/10], Step [200/245], Loss: 1.7602
# Validataion accuracy is: 42.8 %
# Epoch [10/10], Step [100/245], Loss: 1.7595
# Epoch [10/10], Step [200/245], Loss: 1.6832
# Validataion accuracy is: 43.8 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3036
# Epoch [1/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3030
# Epoch [2/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3027
# Epoch [4/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3021
# Epoch [5/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 11.3 %
# Epoch [6/10], Step [100/245], Loss: 2.3024
# Epoch [6/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3020
# Epoch [7/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3027
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3025
# Epoch [9/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3029
# Epoch [10/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3030
# Epoch [1/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 9.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3019
# Epoch [2/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3022
# Epoch [3/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3031
# Epoch [4/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3026
# Epoch [5/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3021
# Epoch [6/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3027
# Epoch [7/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3023
# Epoch [8/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3027
# Epoch [9/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3029
# Epoch [10/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 8.7 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3032
# Epoch [1/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3024
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3029
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3035
# Epoch [4/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3022
# Epoch [5/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3024
# Epoch [7/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3026
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3032
# Epoch [10/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = LeakyReLU(negative_slope=0.01), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3030
# Epoch [1/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3026
# Epoch [2/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3030
# Epoch [3/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 10.5 %
# Epoch [4/10], Step [100/245], Loss: 2.3026
# Epoch [4/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3023
# Epoch [5/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3033
# Epoch [7/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3026
# Epoch [8/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 8.7 %
# Epoch [9/10], Step [100/245], Loss: 2.3024
# Epoch [9/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3023
# Epoch [10/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.0989
# Epoch [1/10], Step [200/245], Loss: 1.8037
# Validataion accuracy is: 36.7 %
# Epoch [2/10], Step [100/245], Loss: 1.7479
# Epoch [2/10], Step [200/245], Loss: 1.6280
# Validataion accuracy is: 42.7 %
# Epoch [3/10], Step [100/245], Loss: 1.5006
# Epoch [3/10], Step [200/245], Loss: 1.5434
# Validataion accuracy is: 45.0 %
# Epoch [4/10], Step [100/245], Loss: 1.5248
# Epoch [4/10], Step [200/245], Loss: 1.4836
# Validataion accuracy is: 45.8 %
# Epoch [5/10], Step [100/245], Loss: 1.4197
# Epoch [5/10], Step [200/245], Loss: 1.3740
# Validataion accuracy is: 49.3 %
# Epoch [6/10], Step [100/245], Loss: 1.4445
# Epoch [6/10], Step [200/245], Loss: 1.4272
# Validataion accuracy is: 48.3 %
# Epoch [7/10], Step [100/245], Loss: 1.2628
# Epoch [7/10], Step [200/245], Loss: 1.3151
# Validataion accuracy is: 51.0 %
# Epoch [8/10], Step [100/245], Loss: 1.2320
# Epoch [8/10], Step [200/245], Loss: 1.2490
# Validataion accuracy is: 49.9 %
# Epoch [9/10], Step [100/245], Loss: 1.2028
# Epoch [9/10], Step [200/245], Loss: 1.3608
# Validataion accuracy is: 50.7 %
# Epoch [10/10], Step [100/245], Loss: 1.2699
# Epoch [10/10], Step [200/245], Loss: 1.2822
# Validataion accuracy is: 50.4 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3032
# Epoch [1/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3029
# Epoch [2/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3018
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3032
# Epoch [4/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3024
# Epoch [6/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3029
# Epoch [7/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3022
# Epoch [8/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3027
# Epoch [10/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3023
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3028
# Epoch [3/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3034
# Epoch [4/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 9.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3022
# Epoch [5/10], Step [200/245], Loss: 2.3018
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3033
# Epoch [6/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3014
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 9.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3026
# Epoch [8/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 10.7 %
# Epoch [9/10], Step [100/245], Loss: 2.3026
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3027
# Epoch [10/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3032
# Epoch [1/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3031
# Epoch [2/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3030
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3026
# Epoch [4/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3025
# Epoch [7/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3034
# Epoch [8/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3033
# Epoch [9/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3024
# Epoch [10/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3031
# Epoch [1/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3021
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3030
# Epoch [4/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3029
# Epoch [5/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3031
# Epoch [6/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3026
# Epoch [7/10], Step [200/245], Loss: 2.3011
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3024
# Epoch [8/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3030
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3034
# Epoch [10/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = LeakyReLU(negative_slope=0.01), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3032
# Epoch [1/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3028
# Epoch [2/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3022
# Epoch [4/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3034
# Validataion accuracy is: 8.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3020
# Epoch [7/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3026
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3023
# Epoch [9/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3023
# Epoch [10/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = Sigmoid(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.1907
# Epoch [1/10], Step [200/245], Loss: 2.1303
# Validataion accuracy is: 19.6 %
# Epoch [2/10], Step [100/245], Loss: 2.0598
# Epoch [2/10], Step [200/245], Loss: 2.0934
# Validataion accuracy is: 20.7 %
# Epoch [3/10], Step [100/245], Loss: 2.0394
# Epoch [3/10], Step [200/245], Loss: 2.0286
# Validataion accuracy is: 25.0 %
# Epoch [4/10], Step [100/245], Loss: 2.0113
# Epoch [4/10], Step [200/245], Loss: 2.0207
# Validataion accuracy is: 27.1 %
# Epoch [5/10], Step [100/245], Loss: 1.9365
# Epoch [5/10], Step [200/245], Loss: 1.9171
# Validataion accuracy is: 29.5 %
# Epoch [6/10], Step [100/245], Loss: 1.8807
# Epoch [6/10], Step [200/245], Loss: 1.9061
# Validataion accuracy is: 31.0 %
# Epoch [7/10], Step [100/245], Loss: 1.9563
# Epoch [7/10], Step [200/245], Loss: 1.9410
# Validataion accuracy is: 32.4 %
# Epoch [8/10], Step [100/245], Loss: 1.8671
# Epoch [8/10], Step [200/245], Loss: 1.8320
# Validataion accuracy is: 34.0 %
# Epoch [9/10], Step [100/245], Loss: 1.8253
# Epoch [9/10], Step [200/245], Loss: 1.9221
# Validataion accuracy is: 35.6 %
# Epoch [10/10], Step [100/245], Loss: 1.8588
# Epoch [10/10], Step [200/245], Loss: 1.8242
# Validataion accuracy is: 34.9 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = Sigmoid(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.2992
# Epoch [1/10], Step [200/245], Loss: 2.2972
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3026
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 10.5 %
# Epoch [3/10], Step [100/245], Loss: 2.3019
# Epoch [3/10], Step [200/245], Loss: 2.3050
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3071
# Epoch [4/10], Step [200/245], Loss: 2.3016
# Validataion accuracy is: 11.2 %
# Epoch [5/10], Step [100/245], Loss: 2.3048
# Epoch [5/10], Step [200/245], Loss: 2.2987
# Validataion accuracy is: 10.5 %
# Epoch [6/10], Step [100/245], Loss: 2.3048
# Epoch [6/10], Step [200/245], Loss: 2.3039
# Validataion accuracy is: 10.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3027
# Epoch [7/10], Step [200/245], Loss: 2.3018
# Validataion accuracy is: 9.8 %
# Epoch [8/10], Step [100/245], Loss: 2.2989
# Epoch [8/10], Step [200/245], Loss: 2.3012
# ...
# Validataion accuracy is: 10.2 %
# Epoch [3/10], Step [100/245], Loss: 2.2989
# Epoch [3/10], Step [200/245], Loss: 2.3038
# Validataion accuracy is: 11.3 %
# Epoch [4/10], Step [100/245], Loss: 2.3041
# Epoch [4/10], Step [200/245], Loss: 2.3038
# Validataion accuracy is: 11.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3087
# Epoch [5/10], Step [200/245], Loss: 2.3003
# Validataion accuracy is: 10.2 %
# Epoch [6/10], Step [100/245], Loss: 2.3112
# Epoch [6/10], Step [200/245], Loss: 2.3077
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3047
# Epoch [7/10], Step [200/245], Loss: 2.3056
# Validataion accuracy is: 10.2 %
# Epoch [8/10], Step [100/245], Loss: 2.3072
# Epoch [8/10], Step [200/245], Loss: 2.3014
# Validataion accuracy is: 10.2 %
# Epoch [9/10], Step [100/245], Loss: 2.2989
# Epoch [9/10], Step [200/245], Loss: 2.3060
# Validataion accuracy is: 10.5 %
# Epoch [10/10], Step [100/245], Loss: 2.3085
# Epoch [10/10], Step [200/245], Loss: 2.2993
# Validataion accuracy is: 11.2 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.0910
# Epoch [1/10], Step [200/245], Loss: 1.9282
# Validataion accuracy is: 31.8 %
# Epoch [2/10], Step [100/245], Loss: 1.8668
# Epoch [2/10], Step [200/245], Loss: 1.8268
# Validataion accuracy is: 36.0 %
# Epoch [3/10], Step [100/245], Loss: 1.8352
# Epoch [3/10], Step [200/245], Loss: 1.8624
# Validataion accuracy is: 37.8 %
# Epoch [4/10], Step [100/245], Loss: 1.7850
# Epoch [4/10], Step [200/245], Loss: 1.8796
# Validataion accuracy is: 39.9 %
# Epoch [5/10], Step [100/245], Loss: 1.8251
# Epoch [5/10], Step [200/245], Loss: 1.7168
# Validataion accuracy is: 43.3 %
# Epoch [6/10], Step [100/245], Loss: 1.7716
# Epoch [6/10], Step [200/245], Loss: 1.6338
# Validataion accuracy is: 43.9 %
# Epoch [7/10], Step [100/245], Loss: 1.7595
# Epoch [7/10], Step [200/245], Loss: 1.5346
# Validataion accuracy is: 44.0 %
# Epoch [8/10], Step [100/245], Loss: 1.6432
# Epoch [8/10], Step [200/245], Loss: 1.6788
# Validataion accuracy is: 42.8 %
# Epoch [9/10], Step [100/245], Loss: 1.5682
# Epoch [9/10], Step [200/245], Loss: 1.6628
# Validataion accuracy is: 42.6 %
# Epoch [10/10], Step [100/245], Loss: 1.5919
# Epoch [10/10], Step [200/245], Loss: 1.6623
# Validataion accuracy is: 45.8 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.1912
# Epoch [1/10], Step [200/245], Loss: 1.9802
# Validataion accuracy is: 18.7 %
# Epoch [2/10], Step [100/245], Loss: 1.9904
# Epoch [2/10], Step [200/245], Loss: 1.9390
# Validataion accuracy is: 30.2 %
# Epoch [3/10], Step [100/245], Loss: 1.8879
# Epoch [3/10], Step [200/245], Loss: 1.8221
# Validataion accuracy is: 35.1 %
# Epoch [4/10], Step [100/245], Loss: 1.8422
# Epoch [4/10], Step [200/245], Loss: 1.8045
# Validataion accuracy is: 36.0 %
# Epoch [5/10], Step [100/245], Loss: 1.8557
# Epoch [5/10], Step [200/245], Loss: 1.8091
# Validataion accuracy is: 36.0 %
# Epoch [6/10], Step [100/245], Loss: 1.7996
# Epoch [6/10], Step [200/245], Loss: 1.8035
# Validataion accuracy is: 37.3 %
# Epoch [7/10], Step [100/245], Loss: 1.8495
# Epoch [7/10], Step [200/245], Loss: 1.6613
# Validataion accuracy is: 36.6 %
# Epoch [8/10], Step [100/245], Loss: 1.7034
# Epoch [8/10], Step [200/245], Loss: 1.7051
# Validataion accuracy is: 37.5 %
# Epoch [9/10], Step [100/245], Loss: 1.7288
# Epoch [9/10], Step [200/245], Loss: 1.8489
# Validataion accuracy is: 41.1 %
# Epoch [10/10], Step [100/245], Loss: 1.7865
# Epoch [10/10], Step [200/245], Loss: 1.8736
# Validataion accuracy is: 41.3 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3023
# Epoch [1/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3032
# Epoch [2/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3013
# Epoch [3/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3021
# Epoch [4/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 8.7 %
# Epoch [5/10], Step [100/245], Loss: 2.3024
# Epoch [5/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3027
# Epoch [6/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3023
# Epoch [7/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 7.8 %
# Epoch [8/10], Step [100/245], Loss: 2.3028
# Epoch [8/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [9/10], Step [100/245], Loss: 2.3026
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3032
# Epoch [10/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3020
# Epoch [1/10], Step [200/245], Loss: 2.3037
# Validataion accuracy is: 7.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3035
# Epoch [2/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 11.2 %
# Epoch [3/10], Step [100/245], Loss: 2.3019
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 10.2 %
# Epoch [4/10], Step [100/245], Loss: 2.3024
# Epoch [4/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3025
# Epoch [5/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3017
# Epoch [6/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 8.7 %
# Epoch [7/10], Step [100/245], Loss: 2.3018
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3022
# Epoch [8/10], Step [200/245], Loss: 2.3018
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3023
# Epoch [9/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 10.7 %
# Epoch [10/10], Step [100/245], Loss: 2.3033
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 11.9 %
# Epoch [2/10], Step [100/245], Loss: 2.3022
# Epoch [2/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3029
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3018
# Epoch [4/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3025
# Epoch [5/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3025
# Epoch [6/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3022
# Epoch [7/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3024
# Epoch [8/10], Step [200/245], Loss: 2.3030
# Validataion accuracy is: 8.7 %
# Epoch [9/10], Step [100/245], Loss: 2.3027
# Epoch [9/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3028
# Epoch [10/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = Tanh(), flag = True
# Epoch [1/10], Step [100/245], Loss: 2.3036
# Epoch [1/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3021
# Epoch [2/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3020
# Epoch [3/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 9.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3024
# Epoch [4/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [5/10], Step [100/245], Loss: 2.3030
# Epoch [5/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 11.3 %
# Epoch [6/10], Step [100/245], Loss: 2.3026
# Epoch [6/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3025
# Epoch [7/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [8/10], Step [100/245], Loss: 2.3023
# Epoch [8/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [9/10], Step [100/245], Loss: 2.3028
# Epoch [9/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3022
# Epoch [10/10], Step [200/245], Loss: 2.3021
# Validataion accuracy is: 10.2 %
#
#
#
#
# Hyperparameters: num_layers = 2, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.0156
# Epoch [1/10], Step [200/245], Loss: 1.9033
# Validataion accuracy is: 32.3 %
# Epoch [2/10], Step [100/245], Loss: 1.8117
# Epoch [2/10], Step [200/245], Loss: 1.7555
# Validataion accuracy is: 34.4 %
# Epoch [3/10], Step [100/245], Loss: 1.7411
# Epoch [3/10], Step [200/245], Loss: 1.8767
# Validataion accuracy is: 41.2 %
# Epoch [4/10], Step [100/245], Loss: 1.6660
# Epoch [4/10], Step [200/245], Loss: 1.6025
# Validataion accuracy is: 43.2 %
# Epoch [5/10], Step [100/245], Loss: 1.4948
# Epoch [5/10], Step [200/245], Loss: 1.6394
# Validataion accuracy is: 43.2 %
# Epoch [6/10], Step [100/245], Loss: 1.4582
# Epoch [6/10], Step [200/245], Loss: 1.5328
# Validataion accuracy is: 43.0 %
# Epoch [7/10], Step [100/245], Loss: 1.5254
# Epoch [7/10], Step [200/245], Loss: 1.5829
# Validataion accuracy is: 45.3 %
# Epoch [8/10], Step [100/245], Loss: 1.4324
# Epoch [8/10], Step [200/245], Loss: 1.3519
# Validataion accuracy is: 46.4 %
# Epoch [9/10], Step [100/245], Loss: 1.5384
# Epoch [9/10], Step [200/245], Loss: 1.5631
# Validataion accuracy is: 45.3 %
# Epoch [10/10], Step [100/245], Loss: 1.4947
# Epoch [10/10], Step [200/245], Loss: 1.4421
# Validataion accuracy is: 46.0 %
#
#
#
#
# Hyperparameters: num_layers = 3, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.1444
# Epoch [1/10], Step [200/245], Loss: 2.0273
# Validataion accuracy is: 19.3 %
# Epoch [2/10], Step [100/245], Loss: 2.0384
# Epoch [2/10], Step [200/245], Loss: 2.0147
# Validataion accuracy is: 21.1 %
# Epoch [3/10], Step [100/245], Loss: 2.0064
# Epoch [3/10], Step [200/245], Loss: 2.0260
# Validataion accuracy is: 20.6 %
# Epoch [4/10], Step [100/245], Loss: 1.9604
# Epoch [4/10], Step [200/245], Loss: 1.9708
# Validataion accuracy is: 22.3 %
# Epoch [5/10], Step [100/245], Loss: 2.0037
# Epoch [5/10], Step [200/245], Loss: 1.9303
# Validataion accuracy is: 24.3 %
# Epoch [6/10], Step [100/245], Loss: 1.8509
# Epoch [6/10], Step [200/245], Loss: 1.8471
# Validataion accuracy is: 29.6 %
# Epoch [7/10], Step [100/245], Loss: 1.8588
# Epoch [7/10], Step [200/245], Loss: 1.7883
# Validataion accuracy is: 30.3 %
# Epoch [8/10], Step [100/245], Loss: 1.8023
# Epoch [8/10], Step [200/245], Loss: 1.7243
# Validataion accuracy is: 35.6 %
# Epoch [9/10], Step [100/245], Loss: 1.7328
# Epoch [9/10], Step [200/245], Loss: 1.6224
# Validataion accuracy is: 37.3 %
# Epoch [10/10], Step [100/245], Loss: 1.6038
# Epoch [10/10], Step [200/245], Loss: 1.6838
# Validataion accuracy is: 36.1 %
#
#
#
#
# Hyperparameters: num_layers = 4, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3026
# Epoch [1/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3033
# Epoch [2/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.8 %
# Epoch [3/10], Step [100/245], Loss: 2.3024
# Epoch [3/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [4/10], Step [100/245], Loss: 2.3018
# Epoch [4/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3023
# Epoch [5/10], Step [200/245], Loss: 2.3027
# Validataion accuracy is: 9.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3028
# Epoch [6/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3021
# Epoch [7/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3029
# Epoch [8/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3034
# Epoch [9/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3032
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.8 %
#
#
#
#
# Hyperparameters: num_layers = 5, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3033
# Epoch [1/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3030
# Epoch [2/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3025
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3029
# Epoch [4/10], Step [200/245], Loss: 2.3022
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3029
# Epoch [5/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 7.9 %
# Epoch [6/10], Step [100/245], Loss: 2.3017
# Epoch [6/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3027
# Epoch [7/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3028
# Epoch [8/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3023
# Epoch [9/10], Step [200/245], Loss: 2.3033
# Validataion accuracy is: 7.9 %
# Epoch [10/10], Step [100/245], Loss: 2.3029
# Epoch [10/10], Step [200/245], Loss: 2.3028
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 10, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3042
# Epoch [1/10], Step [200/245], Loss: 2.3032
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3019
# Epoch [2/10], Step [200/245], Loss: 2.3036
# Validataion accuracy is: 7.9 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 7.9 %
# Epoch [4/10], Step [100/245], Loss: 2.3019
# Epoch [4/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 9.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3027
# Epoch [5/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.8 %
# Epoch [6/10], Step [100/245], Loss: 2.3030
# Epoch [6/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.9 %
# Epoch [7/10], Step [100/245], Loss: 2.3025
# Epoch [7/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3029
# Epoch [8/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3024
# Epoch [9/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [10/10], Step [100/245], Loss: 2.3032
# Epoch [10/10], Step [200/245], Loss: 2.3029
# Validataion accuracy is: 7.9 %
#
#
#
#
# Hyperparameters: num_layers = 15, activation_func = Tanh(), flag = False
# Epoch [1/10], Step [100/245], Loss: 2.3022
# Epoch [1/10], Step [200/245], Loss: 2.3023
# Validataion accuracy is: 7.8 %
# Epoch [2/10], Step [100/245], Loss: 2.3038
# Epoch [2/10], Step [200/245], Loss: 2.3020
# Validataion accuracy is: 8.7 %
# Epoch [3/10], Step [100/245], Loss: 2.3026
# Epoch [3/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %
# Epoch [4/10], Step [100/245], Loss: 2.3027
# Epoch [4/10], Step [200/245], Loss: 2.3039
# Validataion accuracy is: 7.8 %
# Epoch [5/10], Step [100/245], Loss: 2.3024
# Epoch [5/10], Step [200/245], Loss: 2.3031
# Validataion accuracy is: 10.7 %
# Epoch [6/10], Step [100/245], Loss: 2.3021
# Epoch [6/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 7.8 %
# Epoch [7/10], Step [100/245], Loss: 2.3030
# Epoch [7/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.9 %
# Epoch [8/10], Step [100/245], Loss: 2.3031
# Epoch [8/10], Step [200/245], Loss: 2.3024
# Validataion accuracy is: 7.8 %
# Epoch [9/10], Step [100/245], Loss: 2.3029
# Epoch [9/10], Step [200/245], Loss: 2.3026
# Validataion accuracy is: 8.7 %
# Epoch [10/10], Step [100/245], Loss: 2.3027
# Epoch [10/10], Step [200/245], Loss: 2.3025
# Validataion accuracy is: 8.7 %

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/MLP_grid_search.csv').sort_values('val_acc', ascending=False)
del df['train_acc']
df
# Out:
#     N. layers                      Activation  Dropout  val_acc
# 6           2                          ReLU()    False     51.8
# 18          2         PReLU(num_parameters=1)    False     51.3
# 30          2  LeakyReLU(negative_slope=0.01)    False     50.4
# 0           2                          ReLU()     True     48.9
# 12          2         PReLU(num_parameters=1)     True     48.5
# 24          2  LeakyReLU(negative_slope=0.01)     True     47.6
# 54          2                          Tanh()    False     46.0
# 48          2                          Tanh()     True     45.8
# 25          3  LeakyReLU(negative_slope=0.01)     True     43.8
# 49          3                          Tanh()     True     41.3
# 55          3                          Tanh()    False     36.1
# 36          2                       Sigmoid()     True     34.9
# 42          2                       Sigmoid()    False     32.0
# 41         15                       Sigmoid()     True     11.2
# 38          4                       Sigmoid()     True     11.2
# 47         15                       Sigmoid()    False     11.2
# 44          4                       Sigmoid()    False     10.7
# 37          3                       Sigmoid()     True     10.7
# 53         15                          Tanh()     True     10.2
# 39          5                       Sigmoid()     True     10.2
# 40         10                       Sigmoid()     True      8.7
# 27          5  LeakyReLU(negative_slope=0.01)     True      8.7
# 59         15                          Tanh()    False      8.7
# 17         15         PReLU(num_parameters=1)     True      8.7
# 15          5         PReLU(num_parameters=1)     True      8.7
# 52         10                          Tanh()     True      8.7
# 10         10                          ReLU()    False      8.7
# 45          5                       Sigmoid()    False      7.9
# 34         10  LeakyReLU(negative_slope=0.01)    False      7.9
# 50          4                          Tanh()     True      7.9
# 57          5                          Tanh()    False      7.9
# 58         10                          Tanh()    False      7.9
# 35         15  LeakyReLU(negative_slope=0.01)    False      7.9
# 32          4  LeakyReLU(negative_slope=0.01)    False      7.9
# 1           3                          ReLU()     True      7.9
# 29         15  LeakyReLU(negative_slope=0.01)     True      7.9
# 28         10  LeakyReLU(negative_slope=0.01)     True      7.9
# 23         15         PReLU(num_parameters=1)    False      7.9
# 22         10         PReLU(num_parameters=1)    False      7.9
# 20          4         PReLU(num_parameters=1)    False      7.9
# 9           5                          ReLU()    False      7.9
# 33          5  LeakyReLU(negative_slope=0.01)    False      7.8
# 14          4         PReLU(num_parameters=1)     True      7.8
# 3           5                          ReLU()     True      7.8
# 7           3                          ReLU()    False      7.8
# 56          4                          Tanh()    False      7.8
# 8           4                          ReLU()    False      7.8
# 11         15                          ReLU()    False      7.8
# 13          3         PReLU(num_parameters=1)     True      7.8
# 51          5                          Tanh()     True      7.8
# 19          3         PReLU(num_parameters=1)    False      7.8
# 16         10         PReLU(num_parameters=1)     True      7.8
# 2           4                          ReLU()     True      7.8
# 5          15                          ReLU()     True      7.8
# 46         10                       Sigmoid()    False      7.8
# 21          5         PReLU(num_parameters=1)    False      7.8
# 43          3                       Sigmoid()    False      7.8
# 26          4  LeakyReLU(negative_slope=0.01)     True      7.8
# 31          3  LeakyReLU(negative_slope=0.01)    False      7.8
# 4          10                          ReLU()     True      7.8
